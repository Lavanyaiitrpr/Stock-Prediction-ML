# %% [markdown]
# Creating graph for price

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

#Fetching data from yfinance library
df = yf.download('TATAMOTORS.NS',start='2023-01-11') #Date in YYYY-MM-DD format
print(df)
#Plotting graph
plt.plot(df.High , label='High',color = 'green')
plt.plot(df.Low ,label='Low', color = 'red')
plt.grid()

# Adding the title
plt.title("TATA MOTORS")

# Adding the labels
plt.ylabel("Share Price(Rs.)")
plt.xlabel("TimeSeries")
plt.xticks(rotation=90)
plt.legend()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-01-11   415.750000   420.000000   413.549988   418.200012   416.900665
# 2023-01-12   420.299988   420.500000   410.049988   412.250000   410.969147
# 2023-01-13   413.000000   416.350006   408.000000   411.500000   410.221466
# 2023-01-16   413.500000   414.899994   407.600006   413.000000   411.716797
# 2023-01-17   413.000000   419.450012   412.500000   415.299988   414.009644
# ...                 ...          ...          ...          ...          ...
# 2024-04-09  1021.000000  1029.500000  1005.000000  1008.500000  1008.500000
# 2024-04-10  1012.250000  1021.000000  1010.000000  1013.500000  1013.500000
# 2024-04-12  1014.000000  1029.000000  1013.500000  1018.500000  1018.500000
# 2024-04-15   998.099976  1006.950012   978.500000   998.799988   998.799988
# ...

# %% [markdown]
# Graph for Daily Returns

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

#Fetching data from yfinance library
df = yf.download('TATAMOTORS.NS',start='2024-01-01') #Date in YYYY-MM-DD format

day_open=df.Open
day_close=df.Close

day_change= (day_close - day_open) / day_open *100

plt.plot(day_change , color = 'blue')
plt.grid()

# Adding the title
plt.title("TATA MOTORS")

# Adding the labels
plt.ylabel("Daily Returns(%)")
plt.xlabel("TimeSeries")
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# Creating garph for daily log return

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

#Fetching data from yfinance library
df = yf.download('TATAMOTORS.NS',start='2024-01-01') #Date in YYYY-MM-DD format

day_open=df.Open
day_close=df.Close

day_return= (day_close - day_open) / day_open
log_return = np.log(1+ day_return)

plt.plot(log_return , color = 'blue')
plt.grid()

# Adding the title
plt.title("TATA MOTORS")

# Adding the labels
plt.ylabel("Daily Returns(%)")
plt.xlabel("TimeSeries")
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
